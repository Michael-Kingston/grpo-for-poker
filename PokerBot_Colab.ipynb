# %% [markdown]
# # poker bot - colab launcher
#
# use this to run on colab gpu.
#
# ### steps
# 1. upload `pokerbot` folder, `train.py`, `play.py`
# 2. run cells below

# %%
# verify gpu
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")

# %%
# train model
# !python train.py

# %%
# play (experimental)

import sys
import os

# add path
sys.path.append(os.getcwd())

try:
    from play import play
    play()
except ImportError:
    print("upload files first")
